# %% [markdown]
# # Chapter 2 Assignment

# %% [markdown]
# ## Zion Sayavong

# %%
# 3. Enter code to make the Pandas module available.
import pandas as pd

# %%
# 4. Read the data from the ramen-ratings CSV file into a DataFrame.
df = pd.read_csv('ramen-ratings.csv')

# 5. Display the first five rows of data.
df.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %%
# 6. Display the last five rows of data.
df.tail()
# Out:
#          Brand                                            Variety Style  \
# 2572     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573   Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574   Wai Wai                                     Tom Yum Shrimp  Pack
# 2575   Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576  Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# 2572   Vietnam    3.5
# 2573  Thailand    1.0
# 2574  Thailand    2.0
# 2575  Thailand    2.0
# 2576       USA    0.5

# %%
# 7. Display statistical information using the describe() method.
df.describe()
# Out:
#              Stars
# count  2577.000000
# mean      3.654676
# std       1.015331
# min       0.000000
# 25%       3.250000
# 50%       3.750000
# 75%       4.250000
# max       5.000000

# %%
# 8. Display the number of unique values for each column.
df.nunique()
# Out:
# Brand       355
# Variety    2410
# Style         7
# Country      38
# Stars        42
# dtype: int64

# %%
# 9. Display rows only where the country is Vietnam.
df.query('Country == "Vietnam"')
# Out:
#               Brand                                            Variety Style  \
# 18         Binh Tay                                         Mi Hai Cua  Pack
# 52    Uni-President                                    Mushroom Flavor  Pack
# 143        Mum Ngon                                   Lau Tom Chua Cay  Pack
# 224           Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
# 365         Acecook                             Oh! Ricey Pork Flavour  Pack
# ...             ...                                                ...   ...
# 2486       Binh Tay                                   Mi Chay Mushroom  Pack
# 2535        Ve Wong                             Kung-Fu Chicken Flavor  Pack
# 2570        Ve Wong                                      Mushroom Pork  Pack
# 2571          Vifon                                           Nam Vang  Pack
# 2572          Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
#
#       Country  Stars
# 18    Vietnam   4.00
# ...

# %%
# 10.Display only the Brand and Style columns.
df[['Brand','Style']]
# Out:
#                Brand Style
# 0          New Touch   Cup
# 1           Just Way  Pack
# 2             Nissin   Cup
# 3            Wei Lih  Pack
# 4     Ching's Secret  Pack
# ...              ...   ...
# 2572           Vifon  Bowl
# 2573         Wai Wai  Pack
# 2574         Wai Wai  Pack
# 2575         Wai Wai  Pack
# 2576        Westbrae  Pack
#
# [2577 rows x 2 columns]

# %%
# 11.Display only the Country column.
df[['Country']]
# Out:
#        Country
# 0        Japan
# 1       Taiwan
# 2          USA
# 3       Taiwan
# 4        India
# ...        ...
# 2572   Vietnam
# 2573  Thailand
# 2574  Thailand
# 2575  Thailand
# 2576       USA
#
# [2577 rows x 1 columns]

# %%
# 12.Display the data after sorting by the Stars column from high values to low.
df.sort_values("Stars",ascending=False)
# Out:
#                Brand                                            Variety Style  \
# 1585     Prima Taste                            Singapore Laksa La Mian  Pack
# 446         Maruchan  Instant Lunch Chipotle Chicken Flavor Ramen No...   Cup
# 484         Nongshim          Champong Noodle Soup Spicy Seafood Flavor  Pack
# 483           Nissin                              Straits Kitchen Laksa  Pack
# 1613          Nissin                 Raoh Backfat Rich Soy Sauce Flavor  Bowl
# ...              ...                                                ...   ...
# 522             Koyo                 Garlic Pepper Reduced Sodium Ramen  Pack
# 561    Samyang Foods                            Honey & Cheese Big Bowl  Bowl
# 950            Azami                                Kimchee Noodle Soup   Cup
# 2079  Hsin Tung Yang                     Tiny Noodle With Oyster Flavor  Pack
# 52     Uni-President                                    Mushroom Flavor  Pack
#
#             Country  Stars
# ...

# %%
# 13. In the Country column, replace “USA” with “United States”.
df.replace("USA","United States",inplace=True)
df.query('Country == "United States"')
# Out:
#                  Brand                        Variety Style        Country  \
# 2               Nissin  Cup Noodles Chicken Vegetable   Cup  United States
# 11            Yamachan        Yokohama Tonkotsu Shoyu  Pack  United States
# 17            Yamachan              Tokyo Shoyu Ramen  Pack  United States
# 21    Jackpot Teriyaki                     Beef Ramen  Pack  United States
# 23            Yamachan             Sapporo Miso Ramen  Pack  United States
# ...                ...                            ...   ...            ...
# 2513   Sapporo Ichiban                 Chicken Flavor  Pack  United States
# 2543          Maruchan       Ramen Noodle Soup Shrimp  Pack  United States
# 2554            Nissin       Top Ramen Creamy Chicken  Pack  United States
# 2567             Smack                 Vegetable Beef  Pack  United States
# 2576          Westbrae                     Miso Ramen  Pack  United States
#
#       Stars
# 2      2.25
# 11     5.00
# 17     5.00
# 21     5.00
# ...

# %%
# 14. Save this change and then display the first five rows to confirm the change.
df.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#          Country  Stars
# 0          Japan   3.75
# 1         Taiwan   1.00
# 2  United States   2.25
# 3         Taiwan   2.75
# 4          India   3.75

# %%
# 15. Display the number of countries represented in the data.
df.Country.nunique()
# Out:
# 37

# %%
# 16. Display the three countries with the highest average rating. 
df.groupby('Country')['Stars'].mean().sort_values(ascending=False).head(3)
#df.groupby('Country')['Stars'].mean().sort_values(ascending=True).tail(3)
# Out:
# Country
# Brazil      4.350000
# Sarawak     4.333333
# Cambodia    4.200000
# Name: Stars, dtype: float64

# %%
# 17. Display the three countries having the lowest average rating. 
#df.groupby('Country')['Stars'].mean().sort_values(ascending=False).tail(3)
df.groupby('Country')['Stars'].mean().sort_values(ascending=True).head(3)
# Out:
# Country
# Nigeria        1.500000
# Canada         2.243902
# Netherlands    2.483333
# Name: Stars, dtype: float64

# %%
# 18. Duplicate 17 but add code that reports the time taken to run the statement.
# %time df.groupby('Country')['Stars'].mean().sort_values(ascending=True).head(3)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Country
# Nigeria        1.500000
# Canada         2.243902
# Netherlands    2.483333
# Name: Stars, dtype: float64
